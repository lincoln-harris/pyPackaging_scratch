# %%
import pandas as pd
import os
import VCF
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# example vcf
t = VCF.dataframe('vcf/A10_1001000407.vcf')
t
# Out:
#                         CHROM      POS           ID            REF  \
# 0                        chr1   631811            .              C
# 1                        chr1   631861            .              G
# 2                        chr1   631862            .              G
# 3                        chr1   632199            .              C
# 4                        chr1   632403            .              T
# 5                        chr1   632427    rs2853819              T
# 6                        chr1   633887    rs6650105              G
# 7                        chr1   634112            .              T
# 8                        chr1   634229            .              A
# 9                        chr1   634244            .              T
# 10                       chr1   634268            .              C
# 11                       chr1   634798    rs9326626              G
# 12                       chr1  1013541      rs15842              T
# ...

# %%
t['INFO'].iloc[0]
# Out:
# 'AC=2;AF=1.00;AN=2;DP=30;ExcessHet=3.0103;FS=0.000;MLEAC=2;MLEAF=1.00;MQ=3.00;QD=26.37;SOR=2.303'

# %%
def write_vcf(df, outStr_):
    """ routine for writing VCF files, from an existing dataframe. 
    essentially just adding in this horrible vcf header. """
    cwd = os.getcwd()
    with open(cwd + '/vcfheader.txt', 'r') as f:
        header = f.read()

        df['QUAL'] = 60.28
        df['FILTER'] = '.'
        df['INFO'] = 'AC=2;AF=1.00;AN=2;DP=7;ExcessHet=3.0103;FS=0.000;MLEAC=1;MLEAF=0.500;MQ=3.00;QD=30.14;SOR=2.303'

        output_VCF = outStr_
        with open(output_VCF, 'w') as vcf:
            vcf.write(header)

        df.to_csv(output_VCF, sep="\t", mode='a', index=False)

# %%
egfr_mut = pd.DataFrame(columns=['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO'])
egfr_mut
# Out:
# Empty DataFrame
# Columns: [CHROM, POS, ID, REF, ALT, QUAL, FILTER, INFO]
# Index: []

# %%
info = 'AC=2;AF=1.00;AN=2;DP=30;ExcessHet=3.0103;FS=0.000;MLEAC=2;MLEAF=1.00;MQ=3.00;QD=26.37;SOR=2.303'
egfr_mut = egfr_mut.append({'CHROM': 'chr7', 'POS': 55160001, 'ID': '.', 'REF': 'C', 'ALT': 'T', 'QUAL': 52.7, 'FILTER': '.', 'INFO': info}, ignore_index=True)
egfr_mut
# Out:
#   CHROM       POS ID REF ALT  QUAL FILTER  \
# 0  chr7  55160001  .   C   T  52.7      .
#
#                                                 INFO
# 0  AC=2;AF=1.00;AN=2;DP=30;ExcessHet=3.0103;FS=0....

# %%
write_vcf(egfr_mut, 'B1_1000.vcf')

# %%
braf_mut = pd.DataFrame(columns=['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO'])
braf_mut
# Out:
# Empty DataFrame
# Columns: [CHROM, POS, ID, REF, ALT, QUAL, FILTER, INFO]
# Index: []

# %%
info = 'AC=2;AF=1.00;AN=2;DP=30;ExcessHet=3.0103;FS=0.000;MLEAC=2;MLEAF=1.00;MQ=3.00;QD=26.37;SOR=2.303'
braf_mut = braf_mut.append({'CHROM': 'chr7', 'POS': 140900710, 'ID': '.', 'REF': 'C', 'ALT': 'T', 'QUAL': 52.7, 'FILTER': '.', 'INFO': info}, ignore_index=True)
braf_mut
# Out:
#   CHROM        POS ID REF ALT  QUAL FILTER  \
# 0  chr7  140900710  .   C   T  52.7      .
#
#                                                 INFO
# 0  AC=2;AF=1.00;AN=2;DP=30;ExcessHet=3.0103;FS=0....

# %%
write_vcf(braf_mut, 'B1_1004.vcf')
