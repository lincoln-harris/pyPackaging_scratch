# %%
import pandas as pd

# %%
pd.read_csv('validationTable_samples_TEST.csv')
# Out:
#     sample       patient driver_gene          driver_mutation  \
# 0      NaN           NaN         NaN                      NaN
# 1   LT_S74         TH248        EGFR                    del19
# 2   LT_S29         TH183        EGFR                    del19
# 3   LT_S50         TH225        KRAS                     G12C
# 4   LT_S48         TH155        EGFR                    del19
# 5   LT_S21         TH185        EGFR                    L858R
# 6   LT_S42         TH158        EGFR                    del19
# 7   LT_S05         TH103         ALK                   fusion
# 8   LT_S49         TH223        EGFR                    del19
# 9   LT_S35         TH208        EGFR                    L861Q
# 10  LT_S67         TH231         ALK                   fusion
# 11  LT_S51         TH227         ALK  intron 19 rearrangement
# 12  LT_S58         TH179        BRAF                    V600E
# 13  LT_S75         TH266         ALK                   fusion
# ...
